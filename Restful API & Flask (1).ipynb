# %% [markdown]
# THEORY QUESTIONS :

# %%
# What is a RESTful API?

'''
A RESTful API (Representational State Transfer API) is a way for two computer systems to communicate over the internet using the principles of REST architecture. 
It is one of the most common types of web APIs used in modern web and mobile applications.
'''

# %%
#Explain the concept of API specification?
'''
An API specification is a detailed description of how an Application Programming Interface (API) should behave and how developers should interact with it. It acts as a blueprint or contract between the API provider and the API consumer.

Key Concepts of an API Specification:
1.Definition:

It defines the endpoints (URLs), request methods (e.g., GET, POST), expected inputs (parameters, headers, body), and outputs (response formats, status codes) of the API.

2.Structure:
An API specification typically includes:

Endpoints: The available URLs that perform specific actions.

HTTP Methods: Like GET, POST, PUT, DELETE — indicating the action to be performed.

Request Parameters: Query parameters, path variables, headers, and body contents.

Responses: Expected output data, including status codes and data schema (e.g., JSON).

Authentication: How to authenticate (e.g., API keys, OAuth).

Data Formats: The format of request and response data (e.g., JSON, XML).

3.Documentation vs. Specification:

API documentation helps developers understand how to use the API.

API specification is often machine-readable and can be used to generate documentation, validate requests/responses, or auto-generate client/server code.

4.Common Specification Formats:

OpenAPI (formerly Swagger): The most popular standard for RESTful APIs.

RAML (RESTful API Modeling Language)

API Blueprint

GraphQL SDL (Schema Definition Language) — for GraphQL APIs.

5.Use Cases:

Ensures consistency in API behavior.

Enables automated testing and validation.

Facilitates client SDK generation.

Helps with team collaboration across backend and frontend teams.
'''

# %%
# What is Flask, and why is it popular for building APIs ?
'''
Framework Type: Flask is a micro-framework. It provides the essentials for building web applications but leaves most decisions (like database, form validation, or authentication) to the developer by allowing the use of extensions.

Core Components:

WSGI-based (uses Werkzeug)

Jinja2 templating engine

Built-in development server and debugger

RESTful request handling (via routes and methods)

* Why Is Flask Popular for Building APIs?

1.Minimal and Lightweight:

No unnecessary features or bloat — you only include what you need.

Ideal for creating clean and fast RESTful APIs.

2.Quick to Get Started:

Simple syntax and easy setup allow rapid development.

Great for prototyping and learning web development.

3.Flexible and Extensible:

You can add extensions like Flask-RESTful, Flask-JWT, or Flask-SQLAlchemy as needed.

You’re not forced into a specific project structure or toolchain.

4.Clear Routing System:

Easy to define API endpoints using decorators.

from flask import Flask, jsonify

app = Flask(__name__)

@app.route('/api/hello', methods=['GET'])
def hello():
    return jsonify({"message": "Hello, world!"})

5.Strong Community and Ecosystem:

Extensive documentation and community support.

Works well with tools like Swagger/OpenAPI for documentation and Postman for testing.

6.Good for Microservices:

Flask’s small footprint makes it ideal for building APIs in a microservices architecture.

7.Integration with Other Tools:

Easily integrates with databases (e.g., SQLAlchemy, MongoDB), auth systems, and frontend frameworks.
'''

# %%
#What is routing in Flask4?
'''
When a user makes a request to a specific URL, Flask uses its routing system to determine which function should handle that request.
'''

# %%
# How do you create a simple Flask application4?
'''
1. Install Flask

If you haven’t already installed Flask, you can do it using pip:

pip install Flask

2. Create the Application File

Create a Python file, for example, app.py.

3. Write a Basic Flask App

from flask import Flask

# Initialize the Flask app
app = Flask(__name__)

# Define a route
@app.route('/')
def home():
    return 'Hello, Flask!'

# Run the app
if __name__ == '__main__':
    app.run(debug=True)

4. Run the Application
In your terminal or command prompt, run:

python app.py

You’ll see output like:

* Running on http://127.0.0.1:5000/
Open your browser and visit http://127.0.0.1:5000/ to see:
"Hello, Flask!"


'''

# %%
#What are HTTP methods used in RESTful APIs4?
'''
Common HTTP Methods in RESTful APIs:

HTTP   MethodPurpose	CRUD Operation	   Typical Usage Example
GET	   Read data	    Read	           Get a list of users: /users
POST   Create data	    Create  	       Create a new user: /users
PUT	   Replace data	    Update	           Replace a user: /users/123
PATCH  Modify data	    Update	           Update part of user info: /users/123
DELETE Delete data	    Delete	           Delete a user: /users/123
'''

# %%
#What is the purpose of the @app.route() decorator in Flask4?
'''
The @app.route() decorator in Flask is used to bind a URL path to a specific function, called a view function. This is how Flask handles routing, 
directing incoming web requests to the correct function in your application.

Purpose of @app.route()
It tells Flask:

“When a user visits this URL, run this function and return the response.”

🔹 Basic Example

from flask import Flask

app = Flask(__name__)

@app.route('/')
def home():
    return 'Hello, World!'
Here, @app.route('/') tells Flask to run the home() function when someone visits the root URL /.

🔹 Supporting Different URLs
You can create multiple routes for different pages or API endpoints:

@app.route('/about')
def about():
    return 'This is the About page.'

🔹 Dynamic URLs
You can capture parts of the URL as variables:

@app.route('/user/<username>')
def greet_user(username):
    return f'Hello, {username}!'
If you go to /user/Alice, the response will be:
"Hello, Alice!"

🔹 Handling HTTP Methods
By default, routes handle only GET. You can specify others:

@app.route('/submit', methods=['POST'])
def submit():
    return 'Form submitted!'
'''

# %%
#What is the difference between GET and POST HTTP methods4?
'''
BASIC DIFFERENCE :

 Feature            `GET`                            `POST`                            
| ----------------- | ------------------------------ | --------------------------------- |
| **Purpose**       | Retrieve data                  | Submit or send data               |
| **Data Location** | Sent in URL (query string)     | Sent in request body              |
| **Visibility**    | Visible in browser/address bar | Hidden from user                  |
| **Caching**       | Can be cached                  | Not cached by default             |
| **Idempotent?**   | ✅ Yes (safe to repeat)        | ❌ No (may create duplicates)   |
| **Typical Use**   | Read info (e.g. `/products`)   | Submit forms (e.g. login, create) |

'''

# %%
# How do you handle errors in Flask APIs4?
'''
✅ Common Methods to Handle Errors in Flask APIs:

1. Using abort() for HTTP Errors
The abort() function from flask allows you to raise an HTTP error immediately.

from flask import Flask, abort

app = Flask(__name__)

@app.route('/item/<int:item_id>')
def get_item(item_id):
    if item_id > 100:
        abort(404)  # Triggers a 404 Not Found error
    return {"item_id": item_id}

2. Using try-except Blocks
Catch Python exceptions and return appropriate JSON responses.

from flask import Flask, jsonify, request

app = Flask(__name__)

@app.route('/divide')
def divide():
    try:
        x = int(request.args.get('x'))
        y = int(request.args.get('y'))
        result = x / y
        return jsonify({"result": result})
    except ZeroDivisionError:
        return jsonify({"error": "Cannot divide by zero"}), 400
    except Exception as e:
        return jsonify({"error": str(e)}), 500

3. Custom Error Handlers with @app.errorhandler
Define centralized responses for common error codes like 404, 400, or 500.

@app.errorhandler(404)
def not_found(error):
    return jsonify({"error": "Resource not found"}), 404

@app.errorhandler(400)
def bad_request(error):
    return jsonify({"error": "Bad request"}), 400

4. Returning Custom Error Responses
You can return a custom JSON message and status code directly from any route.

@app.route('/login', methods=['POST'])
def login():
    data = request.json
    if not data or 'username' not in data:
        return jsonify({"error": "Missing username"}), 400
    return jsonify({"message": "Login successful"})
'''

# %%
#How do you connect Flask to a SQL database4?
'''
Step-by-Step: Connecting Flask to a SQL Database

1. Install Flask and Flask-SQLAlchemy
Use pip to install the required packages

pip install Flask Flask-SQLAlchemy

2. Set Up Your Flask App
Create a file called app.py:

from flask import Flask
from flask_sqlalchemy import SQLAlchemy

app = Flask(__name__)

# Example: SQLite (you can change this to PostgreSQL, MySQL, etc.)
app.config['SQLALCHEMY_DATABASE_URI'] = 'sqlite:///example.db'
app.config['SQLALCHEMY_TRACK_MODIFICATIONS'] = False

db = SQLAlchemy(app)

# Define a model
class User(db.Model):
    id = db.Column(db.Integer, primary_key=True)
    username = db.Column(db.String(80), unique=True, nullable=False)

# Create the database tables
with app.app_context():
    db.create_all()

@app.route('/')
def index():
    return "Database connected and running!"

if __name__ == '__main__':
    app.run(debug=True)

3. Change the Database URI for Other Databases
Replace the SQLALCHEMY_DATABASE_URI string with the appropriate URI:

PostgreSQL:
'postgresql://username:password@localhost/dbname'

MySQL:
'mysql+pymysql://username:password@localhost/dbname'

SQLite (in-memory):
'sqlite:///:memory:'

You might need extra libraries:

PostgreSQL: pip install psycopg2-binary

MySQL: pip install pymysql


4. Use the Database in Routes
You can query, insert, update, and delete like this:

@app.route('/add')
def add_user():
    new_user = User(username='Alice')
    db.session.add(new_user)
    db.session.commit()
    return "User added!"
'''

# %%
#What is the role of Flask-SQLAlchemy4?
'''
Role of Flask-SQLAlchemy

1. Simplifies SQLAlchemy Integration
Instead of writing all the SQLAlchemy setup manually, Flask-SQLAlchemy handles much of the boilerplate for you. It configures the database connection and manages sessions automatically.

2. Database Connection Management
You configure the database URI in app.config, and Flask-SQLAlchemy manages connections and binds them to the Flask app context.

Example:

app.config['SQLALCHEMY_DATABASE_URI'] = 'sqlite:///example.db'
db = SQLAlchemy(app)

3. Model Definition Using Python Classes
Flask-SQLAlchemy lets you define database tables as Python classes (models), making code more intuitive and maintainable.

Example:

class User(db.Model):
    id = db.Column(db.Integer, primary_key=True)
    username = db.Column(db.String(80), unique=True, nullable=False)

4. Query Interface
It provides a clean and powerful querying API via Model.query, allowing you to do things like:

users = User.query.all()
user = User.query.filter_by(username='Alice').first()

5. Schema Generation
You can automatically create database tables from your models using:

db.create_all()

6. Context-Aware Session Handling
It uses Flask’s application context to manage sessions properly, ensuring that each request has its own clean session.


'''

# %%
#What are Flask blueprints, and how are they useful?
'''
Flask Blueprints are a powerful feature in Flask that help you organize your application into modular components. 
They allow you to group related views, templates, static files, and other resources together, making your Flask project easier to manage, 
especially as it grows.

WHY ARE BLUEPRINTS USEFUL:
| Benefit                    | Description                                                                    |
| -------------------------- | ------------------------------------------------------------------------------ |
| **Modularity**             | Helps break a large app into smaller, reusable pieces.                         |
| **Reusability**            | Blueprints can be reused across projects or apps.                              |
| **Separation of Concerns** | Keeps routes, models, and logic for different parts of your app separate.      |
| **Collaboration**          | Makes it easier for teams to work on different parts of the app independently. |


'''

# %%
#What is the purpose of Flask's request object?
'''
The purpose of Flask’s request object is to provide access to incoming HTTP request data in a web application. 
It’s a global object in Flask, available from the flask module, and is used to retrieve everything that the client sends to the server.


'''

# %%
#How do you create a RESTful API endpoint using Flask?
'''
Step-by-Step: Creating a RESTful API Endpoint in Flask:

1. Install Flask

pip install Flask

2. Create a Simple Flask App (e.g., app.py)

from flask import Flask, request, jsonify

app = Flask(__name__)

# Sample data store (in-memory)
users = [
    {"id": 1, "name": "Alice"},
    {"id": 2, "name": "Bob"}
]

# GET: Return all users
@app.route('/api/users', methods=['GET'])
def get_users():
    return jsonify(users)

# GET: Return a specific user by ID
@app.route('/api/users/<int:user_id>', methods=['GET'])
def get_user(user_id):
    user = next((u for u in users if u['id'] == user_id), None)
    if user:
        return jsonify(user)
    return jsonify({"error": "User not found"}), 404

# POST: Add a new user
@app.route('/api/users', methods=['POST'])
def add_user():
    data = request.get_json()
    new_user = {
        "id": len(users) + 1,
        "name": data['name']
    }
    users.append(new_user)
    return jsonify(new_user), 201

# PUT: Update a user
@app.route('/api/users/<int:user_id>', methods=['PUT'])
def update_user(user_id):
    data = request.get_json()
    user = next((u for u in users if u['id'] == user_id), None)
    if user:
        user['name'] = data['name']
        return jsonify(user)
    return jsonify({"error": "User not found"}), 404

# DELETE: Delete a user
@app.route('/api/users/<int:user_id>', methods=['DELETE'])
def delete_user(user_id):
    global users
    users = [u for u in users if u['id'] != user_id]
    return jsonify({"message": "User deleted"}), 204

if __name__ == '__main__':
    app.run(debug=True)

'''

# %%
#What is the purpose of Flask's jsonify() function?
'''
The purpose of Flask’s jsonify() function is to convert Python data structures (like dictionaries or lists) into 
JSON format and return a proper JSON response with the correct MIME type (application/json) and status code.
'''

# %%
#Explain Flask’s url_for() function?
'''
Flask’s url_for() function is used to dynamically build URLs for your application’s routes using the name of the view function instead of 
hardcoding paths. This makes your code more flexible, maintainable, and less error-prone.


Purpose of url_for():

Generates URLs from route function names (not hardcoded strings).

Automatically adapts to changes in route paths.

Allows adding query parameters easily.


'''

# %%
#How does Flask handle static files (CSS, JavaScript, etc.)?
'''
Flask handles static files—like CSS, JavaScript, and images—using a special folder named static/ in your project directory. By default, 
Flask serves any files placed inside this folder at the /static/ URL path.

Folder Structure Example:
cpp
Copy
Edit
your_project/
│
├── app.py
├── static/
│   ├── style.css
│   └── script.js
└── templates/
    └── index.html

How It Works

Files in the static/ folder are served automatically by Flask at /static/<filename>.

You don't need to create a route to serve them manually.

'''

# %%
#What is an API specification, and how does it help in building a Flask API?
'''
An API specification is a formal, structured description of how an API works—what endpoints it provides, what data it accepts and returns,
and how clients should interact with it.

When building a Flask API, an API specification helps you plan, document, validate, and communicate your API more effectively.

An API specification usually includes:

| Element                | Description                                      |
| ---------------------- | ------------------------------------------------ |
| **Endpoints**          | URLs the API exposes (e.g. `/api/users`)         |
| **HTTP methods**       | Actions supported (GET, POST, PUT, DELETE, etc.) |
| **Request parameters** | URL params, query strings, request bodies        |
| **Response formats**   | JSON structure, HTTP status codes                |
| **Authentication**     | How clients authenticate (e.g., API key, JWT)    |
| **Error handling**     | Standard error formats and codes                 |

How an API Specification Helps in Flask API Development:

| Benefit             | Explanation                                                  |
| ------------------- | ------------------------------------------------------------ |
| **Planning**        | You can design the API before writing code.                  |
| **Consistency**     | All developers follow the same structure and rules.          |
| **Documentation**   | Clients and frontend teams know how to use your API.         |
| **Validation**      | You can use tools to validate requests/responses.            |
| **Testing**         | Helps in writing automated tests using known inputs/outputs. |
| **Code generation** | Some tools can generate Flask boilerplate from specs.        |


'''

# %%
#What are HTTP status codes, and why are they important in a Flask API?
'''
HTTP status codes are three-digit numbers that a server sends in response to a client's request to indicate the outcome of that request. In a Flask API, they are crucial for communicating the result of an operation (success, error, permission issue, etc.) clearly and consistently.

Why HTTP Status Codes Are Important in a Flask API:
| Purpose                 | Explanation                                                                         |
| ----------------------- | ----------------------------------------------------------------------------------- |
| **Clarity for clients** | Tell the client exactly what happened (e.g. success, bad request, unauthorized).    |
| **Standardization**     | Based on universal HTTP protocols — works the same across all web APIs.             |
| **Helps debugging**     | Makes it easier to identify and fix issues when something goes wrong.               |
| **Improves automation** | Tools like Postman, frontend frameworks, and monitoring tools rely on status codes. |

'''

# %%
#How do you handle POST requests in Flask?
'''
Handling POST requests in Flask involves creating a route that explicitly accepts the POST method and then accessing the 
data sent by the client (usually form data or JSON). Here’s a quick guide:

 Steps to Handle POST Requests in Flask:

1. Define a route that accepts POST

from flask import Flask, request, jsonify

app = Flask(__name__)

@app.route('/submit', methods=['POST'])  # Accept POST requests
def submit():
    # Access POST data here
    pass

2. Access POST data
Form data: Use request.form (from HTML form submissions)

JSON data: Use request.get_json() (from API clients sending JSON)

 Example: Handling JSON POST Data:
 
@app.route('/api/data', methods=['POST'])
def api_data():
    data = request.get_json()  # Parse JSON body
    if not data:
        return jsonify({"error": "Missing JSON data"}), 400
    
    name = data.get('name')
    if not name:
        return jsonify({"error": "Missing 'name' field"}), 400

    return jsonify({"message": f"Hello, {name}!"}), 200

 Example: Handling Form Data POST:

@app.route('/form-submit', methods=['POST'])
def form_submit():
    name = request.form.get('name')  # Parse form data
    if not name:
        return "Name is required", 400
    
    return f"Hello, {name}!"
'''

# %%
#How would you secure a Flask API?
'''
Securing a Flask API involves several layers of protection to ensure that only authorized users can access resources, data stays safe, 
and the API resists common attacks. Here’s a rundown of best practices and techniques to secure your Flask API:

1. Use HTTPS
Always serve your API over HTTPS to encrypt data in transit.

Use SSL certificates (Let’s Encrypt is free and popular).

2. Authentication
Implement token-based authentication, commonly using JWT (JSON Web Tokens) or API keys.

Use libraries like:

Flask-JWT-Extended

Flask-HTTPAuth

Flask-Security

Example with JWT:

from flask_jwt_extended import JWTManager, jwt_required, create_access_token

app = Flask(__name__)
app.config['JWT_SECRET_KEY'] = 'super-secret-key'
jwt = JWTManager(app)

@app.route('/login', methods=['POST'])
def login():
    # Authenticate user (check username/password)
    access_token = create_access_token(identity=username)
    return jsonify(access_token=access_token)

@app.route('/protected', methods=['GET'])
@jwt_required()
def protected():
    return jsonify(message="Protected endpoint")
3. Authorization
Restrict access based on user roles/permissions.

Check permissions inside routes to prevent unauthorized actions.

4. Input Validation & Sanitization
Validate all incoming data to prevent injection attacks.

Use libraries like Marshmallow or pydantic for schema validation.

5. Rate Limiting
Protect against brute-force and DoS attacks by limiting requests.

Use extensions like Flask-Limiter:

from flask_limiter import Limiter
from flask_limiter.util import get_remote_address

limiter = Limiter(app, key_func=get_remote_address)

@app.route('/login', methods=['POST'])
@limiter.limit("5 per minute")
def login():
    ...

6. Cross-Origin Resource Sharing (CORS)
Configure CORS to control which domains can access your API.

Use Flask-CORS:

from flask_cors import CORS
CORS(app, resources={r"/api/*": {"origins": "https://yourdomain.com"}})

7. Use Secure Headers
Add HTTP headers like Content-Security-Policy, X-Content-Type-Options, Strict-Transport-Security.

Use Flask-Talisman for easy setup:

from flask_talisman import Talisman
Talisman(app)

8. Error Handling
Avoid exposing stack traces or sensitive info in error messages.

Customize error responses with user-friendly and secure messages.

9. Keep Dependencies Updated
Regularly update Flask and extensions to patch vulnerabilities.

10. Logging & Monitoring
Log API access and errors securely.

Monitor logs for suspicious activities.


'''

# %%
#What is the significance of the Flask-RESTful extension?
'''
The Flask-RESTful extension is a popular Flask add-on designed to simplify building RESTful APIs by providing useful abstractions and 
tools on top of Flask’s basic routing.

 Significance of Flask-RESTful
| Aspect                                       | Explanation                                                                                                                                              |
| -------------------------------------------- | -------------------------------------------------------------------------------------------------------------------------------------------------------- |
| **Resource-based routing**                   | Lets you define resources as classes, mapping HTTP methods (`GET`, `POST`, etc.) to class methods (`get()`, `post()`). This organizes code more cleanly. |
| **Automatic request parsing**                | Includes a built-in request parser (`reqparse`) to handle and validate incoming request data easily.                                                     |
| **Built-in support for common HTTP methods** | Makes it straightforward to implement RESTful behavior by defining methods inside resource classes.                                                      |
| **Standardized error handling**              | Provides consistent and reusable error responses.                                                                                                        |
| **Integration with Flask**                   | Seamlessly integrates with Flask, reusing familiar concepts like decorators and app context.                                                             |
| **Improved maintainability and scalability** | Encourages organizing API endpoints into resource classes, which helps keep larger APIs clean and modular.                                               |

'''

# %%
#What is the role of Flask’s session object?
'''
role of flask session object:
| Purpose                         | Description                                                                                       |
| ------------------------------- | ------------------------------------------------------------------------------------------------- |
| **Maintain user state**         | Keep data like login status, user preferences, or shopping cart info between requests             |
| **Store temporary data**        | Save information that should persist only during a user session (e.g., flash messages, form data) |
| **Secure client-side storage**  | Data is stored in a signed (and optionally encrypted) cookie to prevent tampering                 |
| **Simplify session management** | Abstracts away manual cookie handling and server-side session storage                             |

'''

# %% [markdown]
# PRACTICAL QUESTIONS:

# %%
#How do you create a basic Flask application?
#Step 1: Install Flask
pip install Flask

#Step 2: Create Your Project Structure
my_flask_app/
├── app.py

#Step 3: Write a Basic Flask App (app.py)

from flask import Flask

# Create a Flask app instance
app = Flask(__name__)

# Define a route
@app.route('/')
def hello():
    return 'Hello, Flask!'

# Run the app
if __name__ == '__main__':
    app.run(debug=True)

#Step 4: Run the Application
In your terminal, navigate to your project directory and run

python app.py
You’ll see output like this:

 * Running on http://127.0.0.1:5000/ (Press CTRL+C to quit)
Open your browser and go to http://127.0.0.1:5000/ — you should see:

Hello, Flask!

# %%
#How do you serve static files like images or CSS in Flask?

#Folder Structure Example

your_project/
├── app.py
├── static/
│   ├── css/
│   │   └── style.css
│   ├── images/
│   │   └── logo.png
│   └── js/
│       └── script.js
├── templates/
│   └── index.html

#2. Flask App (app.py)

from flask import Flask, render_template

app = Flask(__name__)

@app.route('/')
def home():
    return render_template('index.html')

if __name__ == '__main__':
    app.run(debug=True)

# %%
#How do you define different routes with different HTTP methods in Flask?
#basic syntax:
@app.route('/your-route', methods=['GET', 'POST', ...])
def your_function():
    ...
#full example with multiple routes and methods :
from flask import Flask, request

app = Flask(__name__)

# Route for GET request
@app.route('/')
def index():
    return 'Welcome to the homepage! (GET)'

# Route for POST request
@app.route('/submit', methods=['POST'])
def submit():
    data = request.form.get('data', 'No data')
    return f'Data received via POST: {data}'

# Route for both GET and POST
@app.route('/login', methods=['GET', 'POST'])
def login():
    if request.method == 'POST':
        username = request.form.get('username')
        return f'Logged in as: {username}'
    return '''
        <form method="post">
            Username: <input type="text" name="username"><br>
            <input type="submit" value="Login">
        </form>
    '''

# Route for PUT
@app.route('/update', methods=['PUT'])
def update():
    return 'Update route (PUT request)'

# Route for DELETE
@app.route('/delete', methods=['DELETE'])
def delete():
    return 'Delete route (DELETE request)'

if __name__ == '__main__':
    app.run(debug=True)

# %%
# How do you render HTML templates in Flask?
#Project Structure

your_project/
├── app.py
├── templates/
│   └── index.html
 
#1. Flask App (app.py)

from flask import Flask, render_template

app = Flask(__name__)

@app.route('/')
def home():
    return render_template('index.html')

if __name__ == '__main__':
    app.run(debug=True)

#2. HTML Template (templates/index.html)

<!DOCTYPE html>
<html>
<head>
    <title>Flask Template</title>
</head>
<body>
    <h1>Welcome to Flask!</h1>
</body>
</html>

# %%
#How can you generate URLs for routes in Flask using url_for?
#Basic Usage of url_for()
#Example:

from flask import Flask, url_for, redirect

app = Flask(__name__)

@app.route('/')
def home():
    return 'Welcome to the homepage!'

@app.route('/about')
def about():
    return 'About Page'

@app.route('/go-to-about')
def go_to_about():
    # Dynamically redirect to the 'about' route
    return redirect(url_for('about'))

if __name__ == '__main__':
    app.run(debug=True)
url_for('about') generates /about

url_for('home') generates /

#✅ Passing Parameters
#If your route has parameters, pass them as keyword arguments to url_for().

@app.route('/user/<username>')
def profile(username):
    return f'User: {username}'

# Generates: /user/john
url_for('profile', username='john')

#✅ Use in HTML Templates
#When rendering templates, use url_for() inside Jinja2 templates to link to routes or static files:

<!-- templates/index.html -->
<a href="{{ url_for('about') }}">About</a>
<img src="{{ url_for('static', filename='images/logo.png') }}">

# %%
#How do you handle forms in Flask?
from flask import Flask, request, render_template

app = Flask(__name__)

@app.route('/form', methods=['GET', 'POST'])
def form():
    if request.method == 'POST':
        name = request.form.get('name')
        return f'Hello, {name}!'
    return '''
        <form method="post">
            Name: <input type="text" name="name">
            <input type="submit">
        </form>
    '''

if __name__ == '__main__':
    app.run(debug=True)

# %%
#How can you validate form data in Flask?
from flask import Flask, request, render_template_string

app = Flask(__name__)

@app.route('/form', methods=['GET', 'POST'])
def form():
    error = None
    if request.method == 'POST':
        name = request.form.get('name')
        if not name:
            error = "Name is required!"
        else:
            return f"Hello, {name}!"
    return render_template_string('''
        <form method="post">
            Name: <input type="text" name="name">
            {% if error %}<p style="color:red;">{{ error }}</p>{% endif %}
            <input type="submit">
        </form>
    ''', error=error)

# %%
#How do you manage sessions in Flask?

#Basic Session Management in Flask:

#Step 1: Import and Configure

from flask import Flask, session, redirect, url_for, request

app = Flask(__name__)
app.secret_key = 'your_secret_key'  # Required for session security

#Step 2: Set Session Variables

@app.route('/login', methods=['POST', 'GET'])
def login():
    if request.method == 'POST':
        username = request.form['username']
        session['username'] = username  # Save user in session
        return redirect(url_for('profile'))
    return '''
        <form method="post">
            <input type="text" name="username">
            <input type="submit">
        </form>
    '''

#Step 3: Access Session Data

@app.route('/profile')
def profile():
    if 'username' in session:
        return f'Logged in as {session["username"]}'
    return 'You are not logged in'

#Step 4: Remove Session Data (Log Out)

@app.route('/logout')
def logout():
    session.pop('username', None)  # Remove username if it exists
    return redirect(url_for('login'))

# %%
#How do you redirect to a different route in Flask?

from flask import Flask, redirect, url_for

app = Flask(__name__)

@app.route('/')
def home():
    return redirect(url_for('hello'))

@app.route('/hello')
def hello():
    return 'Hello there!'

# %%
#How do you handle errors in Flask (e.g., 404)?

from flask import Flask, render_template

app = Flask(__name__)

@app.errorhandler(404)
def not_found(error):
    return render_template('404.html'), 404

# %%
#How do you structure a Flask app using Blueprints?

#Step-by-Step Setup

#1. app/__init__.py — Create the App Factory

from flask import Flask

def create_app():
    app = Flask(__name__)
    app.config['SECRET_KEY'] = 'supersecret'

    # Import and register blueprints
    from .main import main as main_bp
    from .auth import auth as auth_bp
    app.register_blueprint(main_bp)
    app.register_blueprint(auth_bp, url_prefix='/auth')

    return app

#2. app/main/__init__.py

from flask import Blueprint

main = Blueprint('main', __name__)

from . import routes

#3. app/main/routes.py

from . import main

@main.route('/')
def index():
    return "Hello from Main!"

#4. app/auth/__init__.py

from flask import Blueprint

auth = Blueprint('auth', __name__)

from . import routes

#5. app/auth/routes.py

from . import auth

@auth.route('/login')
def login():
    return "Login Page"

#6. run.py — Entry Point

from app import create_app

app = create_app()

if __name__ == '__main__':
    app.run(debug=True)

# %%
#How do you define a custom Jinja filter in Flask?
def reverse_string(s):
    return s[::-1]

from flask import Flask

app = Flask(__name__)

@app.template_filter('reverse')
def reverse_string(s):
    return s[::-1]

@app.template_filter('cut')
def cut(value, substring):
    return value.replace(substring, '')

# %%
#How can you redirect with query parameters in Flask?

from flask import Flask, redirect, url_for, request

app = Flask(__name__)

@app.route('/')
def index():
    # Redirect to /search with a query parameter ?q=flask
    return redirect(url_for('search', q='flask'))

@app.route('/search')
def search():
    query = request.args.get('q')
    return f'Search query: {query}'

# %%
#How do you return JSON responses in Flask?

from flask import Flask, jsonify

app = Flask(__name__)

@app.route('/api/data')
def get_data():
    return jsonify({"name": "Flask", "type": "Web Framework"})

#OUTPUT:
{
  "name": "Flask",
  "type": "Web Framework"
}

# %%
#How do you capture URL parameters in Flask?

from flask import Flask

app = Flask(__name__)

@app.route('/user/<username>')
def show_user(username):
    return f"User: {username}"
